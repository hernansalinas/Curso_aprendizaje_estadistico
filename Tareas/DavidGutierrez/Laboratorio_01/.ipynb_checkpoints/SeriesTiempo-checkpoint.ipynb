# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.loadtxt("http://berkeleyearth.lbl.gov/auto/Global/Land_and_Ocean_complete.txt", comments="%")

# %%
df = pd.DataFrame(data)

# %%
df.columns = ["Year","Month","MonthlyA","MonthlyUnc","AnnuealA","AnnuealUnc","FiveA","FiveUnc","TenA","TenUnc","TwentyA","TwentyUnc"]

# %%
df.head()
# Out:
#      Year  Month  MonthlyA  MonthlyUnc  AnnuealA  AnnuealUnc  FiveA  FiveUnc  \
# 0  1850.0    1.0    -0.760       0.435       NaN         NaN    NaN      NaN
# 1  1850.0    2.0    -0.207       0.420       NaN         NaN    NaN      NaN
# 2  1850.0    3.0    -0.370       0.353       NaN         NaN    NaN      NaN
# 3  1850.0    4.0    -0.605       0.284       NaN         NaN    NaN      NaN
# 4  1850.0    5.0    -0.632       0.293       NaN         NaN    NaN      NaN
#
#    TenA  TenUnc  TwentyA  TwentyUnc
# 0   NaN     NaN      NaN        NaN
# 1   NaN     NaN      NaN        NaN
# 2   NaN     NaN      NaN        NaN
# 3   NaN     NaN      NaN        NaN
# 4   NaN     NaN      NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4128 entries, 0 to 4127
# Data columns (total 12 columns):
# Year          4128 non-null float64
# Month         4128 non-null float64
# MonthlyA      4128 non-null float64
# MonthlyUnc    4128 non-null float64
# AnnuealA      4106 non-null float64
# AnnuealUnc    4106 non-null float64
# FiveA         4010 non-null float64
# FiveUnc       4010 non-null float64
# TenA          3890 non-null float64
# TenUnc        3890 non-null float64
# TwentyA       3650 non-null float64
# TwentyUnc     3650 non-null float64
# dtypes: float64(12)
# memory usage: 387.1 KB

# %%
date = []
for i in range(len(df.Year)):
    date.append(str(int(df.Year[i]))+str(int(df.Month[i])))

# %%
df['Date'] = date

# %%
df.head()
# Out:
#      Year  Month  MonthlyA  MonthlyUnc  AnnuealA  AnnuealUnc  FiveA  FiveUnc  \
# 0  1850.0    1.0    -0.760       0.435       NaN         NaN    NaN      NaN
# 1  1850.0    2.0    -0.207       0.420       NaN         NaN    NaN      NaN
# 2  1850.0    3.0    -0.370       0.353       NaN         NaN    NaN      NaN
# 3  1850.0    4.0    -0.605       0.284       NaN         NaN    NaN      NaN
# 4  1850.0    5.0    -0.632       0.293       NaN         NaN    NaN      NaN
#
#    TenA  TenUnc  TwentyA  TwentyUnc   Date
# 0   NaN     NaN      NaN        NaN  18501
# 1   NaN     NaN      NaN        NaN  18502
# 2   NaN     NaN      NaN        NaN  18503
# 3   NaN     NaN      NaN        NaN  18504
# 4   NaN     NaN      NaN        NaN  18505

# %%
df["Date"] = pd.to_datetime(df["Date"],format='%Y%m')

# %%
df.head()
# Out:
#      Year  Month  MonthlyA  MonthlyUnc  AnnuealA  AnnuealUnc  FiveA  FiveUnc  \
# 0  1850.0    1.0    -0.760       0.435       NaN         NaN    NaN      NaN
# 1  1850.0    2.0    -0.207       0.420       NaN         NaN    NaN      NaN
# 2  1850.0    3.0    -0.370       0.353       NaN         NaN    NaN      NaN
# 3  1850.0    4.0    -0.605       0.284       NaN         NaN    NaN      NaN
# 4  1850.0    5.0    -0.632       0.293       NaN         NaN    NaN      NaN
#
#    TenA  TenUnc  TwentyA  TwentyUnc       Date
# 0   NaN     NaN      NaN        NaN 1850-01-01
# 1   NaN     NaN      NaN        NaN 1850-02-01
# 2   NaN     NaN      NaN        NaN 1850-03-01
# 3   NaN     NaN      NaN        NaN 1850-04-01
# 4   NaN     NaN      NaN        NaN 1850-05-01

# %%
T_serie = df.groupby(pd.Grouper(key='Date', freq='3M')).mean()
T_serie.head()
# Out:
#                    Year  Month  MonthlyA  MonthlyUnc  AnnuealA  AnnuealUnc  \
# Date
# 1850-01-31  1850.000000    1.0 -0.740500    0.410500       NaN         NaN
# 1850-04-30  1850.000000    3.0 -0.390333    0.336500       NaN         NaN
# 1850-07-31  1850.000000    6.0 -0.382833    0.270333 -0.410500    0.148250
# 1850-10-31  1850.000000    9.0 -0.383667    0.266333 -0.414000    0.159000
# 1851-01-31  1850.333333    8.0 -0.393333    0.346167 -0.394833    0.159833
#
#             FiveA  FiveUnc  TenA  TenUnc  TwentyA  TwentyUnc
# Date
# 1850-01-31    NaN      NaN   NaN     NaN      NaN        NaN
# 1850-04-30    NaN      NaN   NaN     NaN      NaN        NaN
# 1850-07-31    NaN      NaN   NaN     NaN      NaN        NaN
# 1850-10-31    NaN      NaN   NaN     NaN      NaN        NaN
# 1851-01-31    NaN      NaN   NaN     NaN      NaN        NaN

# %%
plt.plot(T_serie.index,T_serie.MonthlyA)

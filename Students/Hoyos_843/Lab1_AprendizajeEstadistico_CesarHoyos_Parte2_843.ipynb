# %% [markdown]
# **César Antonio Hoyos Peláez - 1007328843**
#
# **Tarea #1**

# %%
#@title LIBRERIAS
import pandas as pd
import seaborn as sns # Libreria que permite visualizacion de informacion
import matplotlib.pyplot as plt # Libreria para visualizacion

# %%
#@title Solucion Punto 1
pathST = 'https://raw.githubusercontent.com/hernansalinas/Curso_aprendizaje_estadistico/main/datasets/Pandas_data_historical_dataEURUSD.csv'
dfS = pd.read_csv(f"{pathST}")
dfS = dfS.drop('Unnamed: 0', axis=1) # Elimino la primera columna ya que es un index mas.
dfS.head() # Muestro las primeras lineas del dataFrame
# Out:
#                   time     open     high      low    close  tick_volume  \
# 0  2022-07-25 13:00:00  1.02427  1.02430  1.02145  1.02345         3927
# 1  2022-07-25 14:00:00  1.02345  1.02578  1.02288  1.02299         5344
# 2  2022-07-25 15:00:00  1.02303  1.02476  1.02230  1.02457         5524
# 3  2022-07-25 16:00:00  1.02454  1.02548  1.02355  1.02485         5234
# 4  2022-07-25 17:00:00  1.02485  1.02514  1.02030  1.02181         9031
#
#    spread  real_volume  MeanCloseOpen  Diff_Close  Diff_Open  \
# 0       8            0       1.023860    -0.00046   -0.00082
# 1       8            0       1.023220    -0.00046   -0.00082
# 2       8            0       1.023800     0.00158   -0.00042
# 3       8            0       1.024695     0.00028    0.00151
# 4       7            0       1.023330    -0.00304    0.00031
#
#    Diff_MeanCloseOpen
# 0           -0.000640
# 1           -0.000640
# 2            0.000580
# 3            0.000895
# 4           -0.001365

# %%
#@title Solucion Punto 2
dfS.set_index('time', inplace=True)
dfS.head()
# Out:
#                         open     high      low    close  tick_volume  spread  \
# time
# 2022-07-25 13:00:00  1.02427  1.02430  1.02145  1.02345         3927       8
# 2022-07-25 14:00:00  1.02345  1.02578  1.02288  1.02299         5344       8
# 2022-07-25 15:00:00  1.02303  1.02476  1.02230  1.02457         5524       8
# 2022-07-25 16:00:00  1.02454  1.02548  1.02355  1.02485         5234       8
# 2022-07-25 17:00:00  1.02485  1.02514  1.02030  1.02181         9031       7
#
#                      real_volume  MeanCloseOpen  Diff_Close  Diff_Open  \
# time
# 2022-07-25 13:00:00            0       1.023860    -0.00046   -0.00082
# 2022-07-25 14:00:00            0       1.023220    -0.00046   -0.00082
# 2022-07-25 15:00:00            0       1.023800     0.00158   -0.00042
# 2022-07-25 16:00:00            0       1.024695     0.00028    0.00151
# 2022-07-25 17:00:00            0       1.023330    -0.00304    0.00031
#
#                      Diff_MeanCloseOpen
# time
# ...

# %%
#@title Solucion Punto 5
columnas = dfS.columns
j = 0
lista = []
for i in columnas:
  var = i.split('_')
  lista.append(var)


a = 0
columnsPascal = []
for i in lista:
  new_lista =[]
  for j in i:
    new_lista.append(j.capitalize())

  var2 = "".join(new_lista)
  columnsPascal.append(var2)
dfS.columns = columnsPascal
dfS.head()
# Out:
#                         Open     High      Low    Close  TickVolume  Spread  \
# time
# 2022-07-25 13:00:00  1.02427  1.02430  1.02145  1.02345        3927       8
# 2022-07-25 14:00:00  1.02345  1.02578  1.02288  1.02299        5344       8
# 2022-07-25 15:00:00  1.02303  1.02476  1.02230  1.02457        5524       8
# 2022-07-25 16:00:00  1.02454  1.02548  1.02355  1.02485        5234       8
# 2022-07-25 17:00:00  1.02485  1.02514  1.02030  1.02181        9031       7
#
#                      RealVolume  Meancloseopen  DiffClose  DiffOpen  \
# time
# 2022-07-25 13:00:00           0       1.023860   -0.00046  -0.00082
# 2022-07-25 14:00:00           0       1.023220   -0.00046  -0.00082
# 2022-07-25 15:00:00           0       1.023800    0.00158  -0.00042
# 2022-07-25 16:00:00           0       1.024695    0.00028   0.00151
# 2022-07-25 17:00:00           0       1.023330   -0.00304   0.00031
#
#                      DiffMeancloseopen
# time
# ...

# %%
newdfS = dfS[['Close']] # se filtra la columna de cierre
newdfS.head()
# Out:
#                        Close
# time
# 2022-07-25 13:00:00  1.02345
# 2022-07-25 14:00:00  1.02299
# 2022-07-25 15:00:00  1.02457
# 2022-07-25 16:00:00  1.02485
# 2022-07-25 17:00:00  1.02181

# %%
#@title Solucion Punto 6 Parte 1
newdfS['DiffPrice'] = newdfS.diff() # Agrego la nueva columna que tiene info de la operacion diff entre horas
newdfS = newdfS.drop(newdfS.index[0]) # Se elimina la primera fila ya que al hacer el diff aparece un Nan
newdfS.head()
# Out:
# <ipython-input-6-d56e5f86ebe2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdfS['DiffPrice'] = newdfS.diff() # Agrego la nueva columna que tiene info de la operacion diff entre horas
#                        Close  DiffPrice
# time
# 2022-07-25 14:00:00  1.02299   -0.00046
# 2022-07-25 15:00:00  1.02457    0.00158
# 2022-07-25 16:00:00  1.02485    0.00028
# 2022-07-25 17:00:00  1.02181   -0.00304
# 2022-07-25 18:00:00  1.02099   -0.00082

# %%
#@title Solucion Punto 6 Parte 2
sns.set_style('white')
sns.set_context("paper", font_scale = 2)
sns.histplot(data = newdfS, x = 'DiffPrice', bins=100)
# Out:
# <Axes: xlabel='DiffPrice', ylabel='Count'>

# %% [markdown]
# **7. Para el DataFrame, seleccionemos solo los datos correspondientes a 2023**

# %%
#@title Solucion Punto 7
newdfS.index = pd.to_datetime(newdfS.index) # Convertir el índice a valores datetime
df_2023 = newdfS[newdfS.index.year == 2023] # Filtrar los datos correspondientes al año 2023
df_2023.head()
# Out:
#                        Close  DiffPrice
# time
# 2023-01-02 00:00:00  1.06796   -0.00200
# 2023-01-02 01:00:00  1.06965    0.00169
# 2023-01-02 02:00:00  1.07058    0.00093
# 2023-01-02 03:00:00  1.06896   -0.00162
# 2023-01-02 04:00:00  1.06880   -0.00016

# %% [markdown]
# **8. El comando groupby permite agrupar los datos con la periodicidad**
#
# deseada: 1 dias, 2 dias, 1 mes etc. Determina el promedio con una periodicidad de 15 dias, con periodidicidad de 1 semana, y una periodicidad de 1 mes
#
# ```python
#   df.groupby(pd.Grouper(key='time', freq='15D')).mean()
# ```

# %%
Ndf_8_dias = df_2023.groupby(pd.Grouper(freq='8D')).mean()
Ndf_8_dias.head()
# Out:
#                Close  DiffPrice
# time
# 2023-01-02  1.061606   0.000023
# 2023-01-10  1.079192   0.000038
# 2023-01-18  1.084994   0.000088
# 2023-01-26  1.089375  -0.000004
# 2023-02-03  1.075726  -0.000162

# %%
Ndf_15_dias = df_2023.groupby(pd.Grouper(freq='15D')).mean()
Ndf_15_dias.head()
# Out:
#                Close  DiffPrice
# time
# 2023-01-02  1.069361   0.000047
# 2023-01-17  1.085565   0.000015
# 2023-02-01  1.077679  -0.000066
# 2023-02-16  1.063150  -0.000034
# 2023-03-03  1.063186   0.000026

# %%
Ndf_1_mes = df_2023.groupby(pd.Grouper(freq='1M')).mean()
Ndf_1_mes.head()
# Out:
#                Close  DiffPrice
# time
# 2023-01-31  1.077463   0.000031
# 2023-02-28  1.071167  -0.000060
# 2023-03-31  1.070874   0.000049
# 2023-04-30  1.096051   0.000036
# 2023-05-31  1.098980  -0.000069

# %% [markdown]
# **9. Para los datos asociados a los meses de 2023, construya un histograma para cada mes.  Para ello puedo emplear el metodo groupby. Notetese que si no  realiza una operación después de aplicar el metodo grouby, podrias iterar sobre dicho objeto, por ejemplo:**
#
# ```python
# q=df.groupby(pd.Grouper(key='time', freq='15D'))
#
# for name, group in q:
#   print(name, group)
# ```
#
#
# Realiza gráfico análogo a esta (referencia)[https://seaborn.pydata.org/examples/kde_ridgeplot.html]

# %%
#@title Solucion Punto 9 parte 1
q = df_2023.groupby(pd.Grouper(freq='1M')) # Se agrupan los datos con una frecuencia de un mes
L=[] # Se crea una lista vacia
for name, group in q:
  L.append(group) # Se añaden los dataframe a la lista

names = ['January', 'February', 'March', 'April', 'May'] # Dato que solo hay registro de 5 meses se nombran estos
for i in range(0, len(L)):
  L[i]["Etiquetas"] = names[i] # Se añade una columna nueva y se agrega la etiqueta correspondiente a cada mes

df = pd.concat([L[i] for i in range(0, len(L))], axis = 0) # Se concatenan los datos
df
# Out:
# <ipython-input-12-c6b46c182c35>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L[i]["Etiquetas"] = names[i] # Se añade una columna nueva y se agrega la etiqueta correspondiente a cada mes
# <ipython-input-12-c6b46c182c35>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L[i]["Etiquetas"] = names[i] # Se añade una columna nueva y se agrega la etiqueta correspondiente a cada mes
# <ipython-input-12-c6b46c182c35>:8: SettingWithCopyWarning:
# ...

# %%
#@title Solucion Punto 9 parte 2
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(df, row="Etiquetas", hue="Etiquetas", aspect=15, height=.5, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "DiffPrice",
      bw_adjust=.5, clip_on=False,
      fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "DiffPrice", clip_on=False, color="w", lw=2, bw_adjust=.5)

# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)


g.map(label, "DiffPrice")

# Set the subplots to overlap
g.figure.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

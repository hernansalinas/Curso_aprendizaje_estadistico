# %% [markdown]
# ### <a href="https://colab.research.google.com/github/hernansalinas/Curso_aprendizaje_estadistico/blob/main/Assesment/Laboratorio_03_reg_lin_grad_desc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresión lineal:
#
# Supongamos que tenemos un sistema en el que existe un predicor con  **m** valores de entrenamiento,  asi:   $ (x^{(1)}, y^{(1)} ) , (x^{(2)}, y^{(2)}) ... (x^{(m)}, y^{(m)})$
#
#
# |Training|Y      | X_1  |
# |--------|----------|----------|
# |1|$Y^{1}$ | $X_1^{1}$|
# |2|$Y^{2}$ | $X_1^{2}$|
# |.|.         | .        |
# |.|.         | .        |
# |.|.         | .        |
# |m|$Y^{m}$ | $X_1^{m}$  |
#
#
#
# Podemos definir un modelo lineal  como : $h(X) = \theta_0 + \theta_1 X$ con $(\theta_0 , \theta_1)$ parámetros. Nuestro objetivo es encontrar el conjunto de puntos  $(\theta_0 , \theta_1)$ que se encuentan más "cercano" a $Y$ para cada $X$.
#
# Para la optimización, vamos a definir la función de coste **$J(\theta_1,\theta_2 )$** para las muestras de entrenamiento como aquella que garantiza la distancia euclidiana respecto a la hipotesis planteada, así:
#
# \begin{equation}
# J(\theta_1, \theta_2)=\frac{1}{2m} \sum_{i=0}^m ( h_{\theta} (x^{(i)})-y^{(i)})^2
# \end{equation}
#
# Para encontrar los valores  $(\theta_0 , \theta_1)$ se necesita  minimizar la función de coste, que permite obtener los valores más cercanos,  esta minimización podrá ser realizada a través de diferentes metodos el más conocido es el gradiente descendente.
#
# ![](https://github.com/hernansalinas/Curso_aprendizaje_estadistico/blob/main/Sesiones/imagenes/fig00.png?raw=true=50x)

# %% [markdown]
# Supongamos un modelo lineal para realizar la predicción, así nuestro modelo estará basado en la siguiente hipotesis de trabajo:
#
# $h(X) =\theta_0 + \theta_1 X$
#
#
# Reemplando el modelo anterior en la función de coste, tenemos que:
#
#
#
# \begin{equation}
# J(\theta_1, \theta_2)=\frac{1}{2m} \sum_{i=0}^m ( (\theta_0 + \theta_1 X)- y^{(i)})^2
# \end{equation}

# %% [markdown]
# # Laboratorio 03
#
#
# 1. Supongamos que un conjunto de características y datos etiquetados estan dados de la siguiente manera:
#
# Crear un data frame de pandas con los siguientes datos:
#
# |Entrenamiento|Y| X_1 |
# |-|-|-|
# |0|0|0|
# |1|1|1|
# |2|2|2|
# |3|3|3|
# |4|4|4|
# |m|5|5|
#
#
#
#
# 2. Crear una función para calcular la función de coste.
# 3. Asumiendo $\theta_0=0$, encuentre una representacion de gráfica de la función de coste para difeterentes valores de  $\theta_1$, ¿Cuál es el mínimo de la función de coste?, con este valor, grafique sobre los datos del dataframe construido la ecuación y regresión encontrada.
#
#
#
# 4. Suponiendo ahora que los datos de entrenamiento viene dados de la siguiente manera:
#
# |Entrenamiento|Y| X_1 |
# |-|-|-|
# |0|0|0|
# |1|1|1|
# |2|2|2|
# |3|3|3|
# |4|4|4|
# |m|5|5|
#
# Encontrar la función de coste para diferentes valores de $\theta_0$, $\theta_1$.
# Para ello puede emplar los metodos surface y contour dentro de la libreria de matplotlib.  Construya primero con los valores de $\theta_0$, $\theta_1 $ definidos un (np.mesgrid) y evalue  para cada punto $\theta_0$, $\theta_1$ la función de coste.
#
# Para el gráfico 3D puede emplear algo similar a las siguientes lineas de código
#
# ```
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.plot_surface(t0, t1, J )
# ax.contour(t0, t1, J, 200,   linestyles="solid")
# ax.set_xlabel("$\\theta_0$")
# ax.set_ylabel("$\\theta_1$")
# plt.show()
# ```
#
#
# En los casos anteriores la solución solo involucra 1 y 2 parámetros para la representación de la función de coste en  2D y 3D respectivamente. Cuando se tienen más parametros a optmizar, no podemos tener una representacion gráfica análoga a los casos anteriores. Notese además que los datos anteriores no tiene ningún ruido y solo estan realizados de esta manera por motivos didácticos.
#
# 5. Encontrar la expresión teórica para la función de coste en el caso 1D y 2D.

# %% [markdown]
# # Gradiente Descendente
#
#
# Para determinar el minimo,  a través del gradiente descendente puede ser aplicada el siguiente algoritmo:
# - Proponer un número aleatorios inicial $\omega_i$
# - Para descender al mínimo de la función, encontremos un  valor para el cual
# el deriva de la función descenciende, asi:
# \begin{equation}
# \omega_{i+1} = \omega_{i} - \alpha \frac{\mathrm{d}f(\omega_i)}{\mathrm{d}\omega}
# \end{equation}
#
# donde, $\alpha$ es conocido como la tasa de aprendizaje del algoritmo.
#
# - Evaluar $f(\omega_{i+1})$
#
# - Iterar hasta encontrar el minimo de la función
#
#
# 6. Construya un algoritmo en el que emplee el gradiente descente para determinar el minimo de una función, determine el minimo con una error epsilon de  1E-4, pruebe su algoritmo para $f(x)= (x-4)^2$ y al menos 3 valores de $\alpha$
#
#
# 7. Para responder este punto puede consultar la siguiente  página y seguir el video[Ejemplo guia: dotcsv](https://www.youtube.com/watch?v=-_A_AAxqzCg):
#
# Encontrar el mínimo de la siguiente función a través del metodo del gradiente descendente https://en.wikipedia.org/wiki/Gradient_descent:
#
#
# \begin{equation}
# F(x,y) = \sin \left( \frac{1}{2}x^2-\frac{1}{4}y^2 +3\right) \cos (2x+1-e^y)
# \end{equation}
#
#   -  Para ello realice una gráfica de la función en 3D, y un mapa de contourno de la función.
#   - Determine el valor mínimo de la funcion con el metodo del gradiente descendente.

# %% [markdown]
# # Modelo de *machine learning*: Solución general
#
# Un modelo general para solucionar un problema de machinine learning puede ser estructurado como sigue:
#
#
# a. Eliger el modelo a emplear:
# \begin{equation}
# h(X,\Theta)
# \end{equation}
#
# - En el caso de una regresion lineal tenemos que $h(X,\Theta=(\theta_0, \theta_1))$:
#
#     \begin{equation}
#     h(X) = (\theta_0 + \theta_1 X)
#     \end{equation}
#
#
# b. Eligir la funcion de coste :
# -  Metrica Ecuclidiana:
# \begin{equation}
# J(\Theta)=\frac{1}{2m} \sum_{i=1}^m ( h_{\theta} (X^{(i)})-y^{(i)})^2
# \end{equation}
# - [Lista de funciones de coste que pueden ser empleadas](https://jmlb.github.io/flashcards/2018/04/21/list_cost_functions_fo_neuralnets/)
#
#
# c. Aplicar el gradiente descendente iterativamente, hasta encontrar el minimo:
#
# \begin{equation}
# \Delta \vec{\Theta} =  - \alpha \nabla J(\Theta)
# \end{equation}
#
#
#
# - En el caso de una regresion lineal tenemos que $h(X,\Theta=(\theta_0, \theta_1))$:
#
#
# \begin{equation}
# \theta_0 := \theta_0 - \alpha \frac{\partial J}{\partial \theta_0}
# \end{equation}
#
# \begin{equation}
# \theta_1 := \theta_1 - \alpha \frac{\partial J}{\partial \theta_1}
# \end{equation}

# %% [markdown]
# 8. Empleando los siguientes datos :
#
# ```
# X = np.linspace(0, 1, 100)
# y = 0.2 + 0.2*X + 0.02*np.random.random(100)
# ```
#
# y las herramientas desarrolladas en los apartados anteriores,
# construya un algorítmo que permita determinar una regresión lineal.
#
# 9. Compare su resultado empleando la libreria linearRegresion() de sklearn.

# %% [markdown]
# Hint:
#
# Pueden comprobar la solución de la superficie con el siguiente cálculo:
#
#
# \begin{equation}
# J(\Theta)=\frac{1}{2m} \sum_{i=1}^m ( h_{\theta} (X^{(i)})-y^{(i)})^2
# \end{equation}
#
#
#
# Sea $\Theta^T = [\theta_0,\theta_1]$
#
#
# \begin{equation}
# X =
# \begin{bmatrix}
# 1& 1 & 1 & .&.&.&1\\
# x_1^{(1)}&x_1^{(2)} & x_1^{(3)} & .&.&.&x_1^{(m)}\\
# \end{bmatrix}_{(n+1) \times m}
# \end{equation}
#
# Luego:
#
# \begin{equation}
# \Lambda = \Theta^T X=
# \begin{bmatrix}
# (\theta_0 1 + \theta_1 x_1^1)\\
# (\theta_0 1 + \theta_1 x_1^2)\\
# .\\
# .\\
# .\\
# (\theta_0 1 + \theta_1 x_1^m)\\
# \end{bmatrix}
# \end{equation}
#
#
# Sumando sobre todos los elementos de matriz se puede encontrar la función de coste $J = \mathrm{\Lambda.mean()^2}$.

# %% [markdown]
# 1. Supongamos que un conjunto de características y datos etiquetados estan dados de la siguiente manera:
#
# Crear un data frame de pandas con los siguientes datos:
#
# |Entrenamiento|Y| X_1 |
# |-|-|-|
# |0|0|0|
# |1|1|1|
# |2|2|2|
# |3|3|3|
# |4|4|4|
# |m|5|5|

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



df = pd.DataFrame()
df['X_1'] = [0,1,2,3,4,5]
df['Y'] = [0,1,2,3,4,5]

# %%
df
# Out:
#    X_1  Y
# 0    0  0
# 1    1  1
# 2    2  2
# 3    3  3
# 4    4  4
# 5    5  5

# %% [markdown]
# 2. Crear una función para calcular la función de coste.

# %%
def h(X,theta_0,theta_1):
  theta = np.array([theta_0, theta_1],dtype=object).reshape(1,2)  #Vectorizamos los valores de theta
  X_vect = np.array([np.ones(len(X)),X])  #Tomamos las características y le sumamos una columna de unos
  h = theta@X_vect   #Encontramos h
  return h[0]


def Fun_coste(Y,h):
  L = 0.5*(h-Y)**2   #Con el valor de h calculamos la función de coste
  return L.mean()

# %%
theta_0 = 0 #Se supone theta_0 = 0
theta_1 = 2
n = 100  #Número de puntos
X = np.array(df['X_1'])
Y = np.array(df['Y'])
L = np.zeros(n)
theta_1i = np.linspace(-2,4,n) #Tomamos una arreglo de números para el valor de theta 1
#Para ver el comportamiento de la función de coste


for i in range(n):
  L[i] = Fun_coste(Y,h(X,theta_0,theta_1i[i]))  #Calculamos la función de coste para cada theta1

# %% [markdown]
# 3. Asumiendo $\theta_0=0$, encuentre una representacion de gráfica de la función de coste para difeterentes valores de  $\theta_1$, ¿Cuál es el mínimo de la función de coste?, con este valor, grafique sobre los datos del dataframe construido la ecuación y regresión encontrada.

# %%
# %matplotlib inline
plt.plot(theta_1i,L)  #Graficamos la función de coste respecto a theta. Esta función es la que queremos minimizar
plt.show()

# %%
plt.plot(X,h(X,theta_0,theta_1i[np.argmin(L)]))
plt.scatter(X,Y,color = 'red')
plt.show()

# %% [markdown]
# 4. Suponiendo ahora que los datos de entrenamiento viene dados de la siguiente manera:
#
# |Entrenamiento|Y| X_1 |
# |-|-|-|
# |0|0|0|
# |1|1|1|
# |2|2|2|
# |3|3|3|
# |4|4|4|
# |m|5|5|
#
# Encontrar la función de coste para diferentes valores de $\theta_0$, $\theta_1$.
# Para ello puede emplar los metodos surface y contour dentro de la libreria de matplotlib.  Construya primero con los valores de $\theta_0$, $\theta_1 $ definidos un (np.mesgrid) y evalue  para cada punto $\theta_0$, $\theta_1$ la función de coste.
#
# Para el gráfico 3D puede emplear algo similar a las siguientes lineas de código
#
# ```
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.plot_surface(t0, t1, J )
# ax.contour(t0, t1, J, 200,   linestyles="solid")
# ax.set_xlabel("$\\theta_0$")
# ax.set_ylabel("$\\theta_1$")
# plt.show()
# ```
#
#
# En los casos anteriores la solución solo involucra 1 y 2 parámetros para la representación de la función de coste en  2D y 3D respectivamente. Cuando se tienen más parametros a optmizar, no podemos tener una representacion gráfica análoga a los casos anteriores. Notese además que los datos anteriores no tiene ningún ruido y solo estan realizados de esta manera por motivos didácticos.

# %%
n=100
theta_0i = np.linspace(-2,2,n)
theta_1j = np.linspace(-2,2,n)
theta0 , theta1 = np.meshgrid(theta_0i,theta_1j) #Creamos una matriz para distintos valores de theta0 y theta 1


Li = np.zeros(n)
Lj = np.zeros(n)
L,Ly = np.meshgrid(Li,Lj) #Creamos una matriz vacía de valores para la función de coste

print (np.shape(L))


for i in range(n):
  for j in range(n):
    L[i,j] = Fun_coste(Y,h(X,theta0[i,j],theta1[i,j]))  #Encontramos la función de coste para ambos valores de theta y guardamos los valores en la matriz
# Out:
# (100, 100)

# %%
for i, r in enumerate(theta_0i):
  for j, t in enumerate(theta_1j):
    L[i,j] = Fun_coste(Y,h(X,r,t))

# %% [markdown]
# Graficamos la función de coste 2-dimensional

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Datos de ejemplo
theta0 = np.linspace(-10, 10, 100)
theta1 = np.linspace(-10, 10, 100)
theta0, theta1 = np.meshgrid(theta0, theta1)
  # Ejemplo de función de costo

# Crear una figura de Matplotlib
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(theta0, theta1, L, cmap='viridis')
ax.contour(theta0, theta1, L, 50, linestyles="solid", colors='red')
ax.set_xlabel("$\\theta_0$")
ax.set_ylabel("$\\theta_1$")
ax.set_zlabel("$L(\\theta_0, \\theta_1)$")
ax.set_title('Gráfico en 3D')
ax.set_zlim(0,20)

# Convierte la figura de Matplotlib a una figura interactiva de Plotly
fig = go.Figure(data=go.Surface(z=L, colorscale='viridis'))
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                                  highlightcolor="limegreen", project_z=True))
fig.update_layout(scene=dict(xaxis_title="$\\theta_0$", yaxis_title="$\\theta_1$", zaxis_title="$L(\\theta_0, \\theta_1)$"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="07f9fa6b-8a02-483d-9cf3-0d90593bb85f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f9fa6b-8a02-483d-9cf3-0d90593bb85f")) {                    Plotly.newPlot(                        "07f9fa6b-8a02-483d-9cf3-0d90593bb85f",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"z":[[58.25,56.944350916573136,55.65366629255518,54.37794612794613,53.11719042274598,51.87139917695473,50.640572390572395,49.42471006359895,48.22381219603441,47.03787878787878,45.86690983913206,44.710905349794245,43.56986531986532,42.44378974934531,41.33267863823419,40.23653198653199,39.155349794238674,38.089132061354285,37.03787878787878,36.001589973812195,34.9802656191545,33.97390572390572,32.982510288065846,32.00607931163486,31.0446127946128,30.098110736999626,29.16657313879536,28.25,27.34839132061354,26.46174710063599,25.59006734006734,24.733352038907594,23.89160119715675,23.064814814814813,22.252992891881778,21.456135428357644,20.674242424242426,19.907313879536105,19.155349794238678,18.418350168350166,17.696315001870556,16.989244294799846,16.29713804713805,15.619996258885147,14.957818930041151,14.310606060606057,13.67835765057987,13.061073699962586,12.458754208754208,11.87139917695473,11.29900860456416,10.741582491582486,10.199120838009724,9.671623643845868,9.159090909090907,8.661522633744854,8.178918817807704,7.71127946127946,7.25860456416012,6.820894126449679,6.398148148148148,5.990366629255514,5.5975495697717905,5.219696969696966,4.856808829031049,4.508885147774037,4.175925925925923,3.857931163486718,3.5549008604564136,3.2668350168350155,2.9937336326225186,2.7355967078189285,2.4924242424242418,2.2642162364384566,2.0509726898615783,1.8526936026936005,1.6693789749345296,1.501028806584362,1.3476430976430962,1.2092218481107366,1.085765057987279,0.9772727272727266,0.8837448559670774,0.8051814440703323,0.7415824915824913,0.6929479985035537,0.6592779648335202,0.6405723905723905,0.6368312757201645,0.6480546202768428,0.6742424242424244,0.7153946876169098,0.7715114104003001,0.842592592592593,0.9286382341937912,1.0296483352038917,1.145622895622896,1.276561915450806,1.4224653946876178,1.5833333333333333],[57.86697785940209,56.56540999217767,55.278806584362144,54.00716763595553,52.75049314695779,51.50878311736898,50.282037547189056,49.07025643641805,47.87343978505595,46.691587593102746,45.52469986055845,44.372776587423054,43.23581777369657,42.113823419378974,41.00679352447029,39.91472808897052,38.83762711287963,37.77549059619767,36.728318538924604,35.69611094106043,34.678867802605176,33.67658912355881,32.68927490392138,31.716925143692816,30.75953984287317,29.81711900146243,28.889662619460598,27.97717069686767,27.07964323368363,26.19708022990851,25.32948168554229,24.47684760058497,23.639177975036556,22.81647280889705,22.008732102166437,21.215955854844736,20.438144066931944,19.67529673842805,18.92741386933306,18.194495459646973,17.476541509369792,16.77355201850151,16.085526987042133,15.412466414991668,14.754370302350097,14.111238649117434,13.483071455293675,12.869868720878818,12.271630445872868,11.68835663027582,11.120047274087677,10.566702377308433,10.028321939938097,9.50490596197667,8.996454443424136,8.502967384280515,8.02444478454579,7.560886644219974,7.112292963303063,6.678663741795051,6.259998979695948,5.856298677005744,5.467562833724448,5.093791449852051,4.734984525388564,4.391142060333979,4.062264054688295,3.748350508451518,3.449401421623641,3.165416794204672,2.8963966261946026,2.642 ...

# %%
L1=L
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(theta0, theta1, L1 )
ax.contour(theta0, theta1, L1, 50, linestyles="solid", color='red')
ax.set_xlabel("$\\theta_0$")
ax.set_ylabel("$\\theta_1$")
ax.set_zlabel("$L(\\theta_0, \\theta_1)$")

# ax.set_zlim(0,20)
#ax.set_ylim(-10,10)
plt.show()
# Out:
# <ipython-input-10-96f5854d6f13>:5: UserWarning:
#
# The following kwargs were not used by contour: 'color'

# %% [markdown]
# # Gradiente Descendente
#
#
# Para determinar el minimo,  a través del gradiente descendente puede ser aplicada el siguiente algoritmo:
# - Proponer un número aleatorios inicial $\omega_i$
# - Para descender al mínimo de la función, encontremos un  valor para el cual
# el deriva de la función descenciende, asi:
# \begin{equation}
# \omega_{i+1} = \omega_{i} - \alpha \frac{\mathrm{d}f(\omega_i)}{\mathrm{d}\omega}
# \end{equation}
#
# donde, $\alpha$ es conocido como la tasa de aprendizaje del algoritmo.
#
# - Evaluar $f(\omega_{i+1})$
#
# - Iterar hasta encontrar el minimo de la función
#
#
# 6. Construya un algoritmo en el que emplee el gradiente descente para determinar el minimo de una función, determine el minimo con una error epsilon de  1E-4, pruebe su algoritmo para $f(x)= (x-4)^2$ y al menos 3 valores de $\alpha$

# %%
from sqlalchemy.sql.compiler import WARN_LINTING
def df(x):
  return 2*(x-4)

def f(x):
  return (x-4)**2

def gradiente_des(w_ini,a):

  #La derivada de la función no se calcula dentro de esta función
  # Suponemos que tenemos la derivada
  w = w_ini - a*df(w_ini)
  while f(w_ini)>f(w):
    w_ini = w
    w = w_ini - a*df(w_ini) #Se reduce w según el gradiente, en este caso la derivada

  return w


w_ini = 2
a = [0.3,0.5,0.2]
for i in a:
  print('Para un valor de alpha {} el valor de w es: {}'.format(i,gradiente_des(w_ini,i)))
# Out:
# Para un valor de alpha 0.3 el valor de w es: 4.0
# Para un valor de alpha 0.5 el valor de w es: 4.0
# Para un valor de alpha 0.2 el valor de w es: 3.9999999999999996

# %% [markdown]
# 7. Para responder este punto puede consultar la siguiente  página y seguir el video[Ejemplo guia: dotcsv](https://www.youtube.com/watch?v=-_A_AAxqzCg):
#
# Encontrar el mínimo de la siguiente función a través del metodo del gradiente descendente https://en.wikipedia.org/wiki/Gradient_descent:
#
#
# \begin{equation}
# F(x,y) = \sin \left( \frac{1}{2}x^2-\frac{1}{4}y^2 +3\right) \cos (2x+1-e^y)
# \end{equation}
#
#   -  Para ello realice una gráfica de la función en 3D, y un mapa de contourno de la función.
#   - Determine el valor mínimo de la funcion con el metodo del gradiente descendente.

# %%
import sympy as sp

f = lambda th: np.sin(0.5*th[0]**2 - (1/4)*th[1]**2 + 3)*np.cos(2*th[0]+1-np.exp(th[1]))

res = 100

X = np.linspace(-2,2,res)
Y = np.linspace(-2,2,res)
Z = np.zeros((res,res))

for ix , x in enumerate(X):
  for iy, y in enumerate(Y):
    Z[iy,ix] = f([x,y])

plt.contourf(X,Y,Z,100)

theta = np.random.rand(2)*4 - 2
plt.plot(theta[0],theta[1],'o', color = "black" )


T = np.copy(theta)

grad = np.zeros(2)
lr = 0.0001
h = 0.001



for i in range(10000):
  for it, th in enumerate(theta):

    T = np.copy(theta)
    T[it] += h

    deriv = (f(T) - f(theta)) / h

    grad[it] = deriv

  theta -= lr*grad

  if (i % 100 == 0):
    plt.plot(theta[0],theta[1], "r.")

plt.show()

# %% [markdown]
# Haciendo una adaptación de mi código de gradiente descendente 1D a 2D se obtiene:

# %%
from scipy.optimize import approx_fprime


def gradiente_des2D(w_inix,w_iniy,a,f):

  gradx, grady = approx_fprime([w_inix,w_iniy], f, epsilon=1e-6)

  i = 0
  w_x = w_inix - a*gradx
  w_y = w_iniy - a*grady

  while f([w_inix,w_iniy])>f([w_x, w_y]):
    i += 1

    w_inix = w_x
    w_iniy = w_y
    gradx, grady = approx_fprime([w_inix,w_iniy], f, epsilon=1e-6)
    w_x = w_inix - a*gradx
    w_y = w_iniy - a*grady

    if i % 10 == 0:
      plt.plot(w_x,w_y,'ro')
  return w_x, w_y

# %%
plt.contourf(X,Y,Z,100)

lf = 0.01
theta = np.random.rand(2)*4 - 2
plt.plot(theta[0],theta[1],'o', color = "black" )
plt.colorbar()
x_min, y_min = gradiente_des2D(theta[0],theta[1],lf,f)
print('El punto mínimo está localizado en: ({},{})'.format(round(x_min,2), round(y_min,2)))
plt.show()
# Out:
# El punto mínimo está localizado en: (0.32,1.6)

# %% [markdown]
# 8. Empleando los siguientes datos :
#
# ```
# X = np.linspace(0, 1, 100)
# y = 0.2 + 0.2*X + 0.02*np.random.random(100)
# ```
#
# y las herramientas desarrolladas en los apartados anteriores,
# construya un algorítmo que permita determinar una regresión lineal.
#
# 9. Compare su resultado empleando la libreria linearRegresion() de sklearn.

# %%
N = 100
X = np.linspace(0, 1, N).T
Y = 0.2 + 0.2*X + 0.02*np.random.random(N)

df = pd.DataFrame({'X':X, "Y":Y})
df["ones"] = 1

x = df[["ones", 'X']].values.T
y = df.Y.values.reshape(1, N)

# %% [markdown]
# Tomamos la clase de regresión lineal que creamos en la clase

# %%
class linearRegresion():
  def __init__(self, X, Y):
    features=np.shape(X)[0]
    self.theta =  np.random.random(features).reshape(features, 1)
    self.X = X
    self.Y = Y
    self.H =  self.theta.T@self.X
    self.J = []

  def model(self):
   self.H = self.theta.T@self.X

  def cost(self):
    J1 = (self.H-self.Y)**2
    self.J.append(0.5*J1.mean())

  def update_theta(self,learning_rate):
    self.theta = self.theta - (learning_rate * np.dot((self.H-self.Y), self.X.T)).T

  def fit(self, learning_rate):
    for i in range(0, 100):
      self.model()
      self.cost()
      self.update_theta(learning_rate)

# %%
Regresion = linearRegresion(x,y)

Regresion.fit(0.01)
print('Coeficientes: ', Regresion.theta)
# Out:
# Coeficientes:  [[0.20909651]
#  [0.20043555]]

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
X = X.reshape(-1, 1)
regression.fit(X, Y)


coeficiente_intercept = regression.intercept_
coeficientes_pendiente = regression.coef_

print('Coeficientes: ', [coeficiente_intercept, coeficientes_pendiente[0]])
# Out:
# Coeficientes:  [0.20900309983437465, 0.2006098395491407]

# %% [markdown]
# Notamos que las aproximaciones son muy similares y diefiente a partir del 4 dígito decimal
